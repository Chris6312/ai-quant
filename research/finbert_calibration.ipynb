# %% [markdown]
# # FinBERT Calibration
#
# Calibrate FinBERT sentiment scores against realized forward returns. Measure whether high-confidence bullish articles reliably precede positive next-5-day returns and tune the news confidence threshold.

# %%
import matplotlib.pyplot as plt
import pandas as pd
from transformers import pipeline
import torch

# %%
# TODO: score news articles with FinBERT and compare predictions to realized forward returns.
# TODO: evaluate calibration curves by confidence bucket.
# TODO: tune NEWS_MIN_CONFIDENCE based on measured precision and recall.
