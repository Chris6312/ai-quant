# %% [markdown]
# # Feature Importance Review
#
# Load the latest training results and visualise which features contribute most to the stock and crypto models. Identify candidates for pruning and candidates for promotion.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
import shap

from app.ml.trainer import TrainResult

# %%
# TODO: load the latest TrainResult artifacts for stock and crypto models.
# TODO: rank feature importances and plot the top contributors.
# TODO: identify near-zero features for pruning and high-value research features for promotion.
