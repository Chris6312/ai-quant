# %% [markdown]
# # Congress Signal Analysis
#
# Analyse historical congressional trade disclosures versus forward stock returns. Measure signal alpha at 5, 10, and 30-day windows, and identify which committees produce the highest-alpha signals.

# %%
import pandas as pd
from sqlalchemy import create_engine

from app.db.models import CongressTradeRow

# %%
# TODO: load CongressTradeRow data and align disclosure timestamps with forward returns.
# TODO: compute alpha for 5, 10, and 30-day horizons.
# TODO: rank committees by realized signal quality and significance.
