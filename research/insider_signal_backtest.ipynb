# %% [markdown]
# # Insider Signal Backtest
#
# Backtest insider buy signals from Form 4 open-market purchases above $50k against forward returns. Measure CEO, CFO, and Director signal quality separately.

# %%
import pandas as pd
from sqlalchemy import create_engine

from app.db.models import InsiderTradeRow

# %%
# TODO: filter Form 4 open-market purchases above the minimum value threshold.
# TODO: backtest forward returns and compare CEO, CFO, and Director cohorts.
# TODO: summarize hit rate, average alpha, and drawdown by officer type.
